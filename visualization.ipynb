# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
import lib.preprocess.user_load_data as user_load_data
import lib.preprocess.pipline as pipline
import lib.visualization.visualization as viz
import importlib

importlib.reload(user_load_data)
importlib.reload(pipline)
importlib.reload(viz)
# Out:
# <module 'lib.preprocess.pipline' from 'D:\\Project\\Python\\household-electricity\\lib\\preprocess\\pipline.py'>

# %%
dataSet = pipline.load_preprocess_dataSet('2018-08-28-21-04-49_max_min_sum_w_dataSet.csv')
dataSet.head()
# Out:
#            userId reportTime  period_1  period_2  period_3  period_4  \
# uuid
# 1020170801      1 2017-08-01    907.80     701.2     964.2    817.75
# 1020170802      1 2017-08-02    693.80     694.8     947.6   1022.60
# 1020170803      1 2017-08-03    974.25    1343.2    1513.0    844.80
# 1020170804      1 2017-08-04   1090.25     979.6     699.8    914.20
# 1020170805      1 2017-08-05   1080.50    1151.0    1109.6    883.20
#
#             period_5  period_6  period_7  period_8    ...     period_90  \
# uuid                                                  ...
# 1020170801     813.6    1037.8     723.2    494.60    ...        1840.6
# 1020170802    1286.6     848.6    1360.0   1220.00    ...        1537.0
# 1020170803    1148.4    1326.2    1319.8    879.00    ...         902.0
# 1020170804     674.6     676.8     752.6    887.33    ...        3004.6
# 1020170805    1106.2    1104.6    1153.0    954.25    ...        3130.8
#
#             period_91  period_92  period_93  period_94  period_95  period_96  \
# uuid
# 1020170801    1320.40     1093.4      907.0      893.0      906.8     469.75
# 1020170802    1150.20     1271.0     1236.4     1567.8     1151.8    1392.60
# 1020170803     797.00      962.8      791.4      951.4      884.2     734.80
# 1020170804    2508.75     1623.0     1172.2     1183.8      889.0    1394.00
# 1020170805    2971.50     1988.4     1750.8     1204.2     1276.0    1221.00
#
#               wMax    wMin      wSum
# uuid
# 1020170801  4595.2  135.50  20667.67
# 1020170802  3382.5  176.75  21649.61
# 1020170803  4585.4  149.20  32833.36
# 1020170804  5295.8  137.20  24774.05
# 1020170805  3130.8  169.60  28111.41
#
# [5 rows x 101 columns]

# %%
viz.plot_dataSet(dataSet, userId='1', startTime='2017-12-20', endTime='2018-01-10')

# %%
viz.plot_dataSet(dataSet, userId=['1', '3', '5', '7', '11', '15', '20', '24'],
                 startTime='2017-12-20', endTime='2018-01-10', ncols=3)
